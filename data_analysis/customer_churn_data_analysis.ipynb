# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.shape
# Out:
# (7043, 21)

# %%
# Count the number of non-missing value for each variables
df.count()
# Out:
# customerID          7043
# gender              7043
# SeniorCitizen       7043
# Partner             7043
# Dependents          7043
# tenure              7043
# PhoneService        7043
# MultipleLines       7043
# InternetService     7043
# OnlineSecurity      7043
# OnlineBackup        7043
# DeviceProtection    7043
# TechSupport         7043
# StreamingTV         7043
# StreamingMovies     7043
# Contract            7043
# PaperlessBilling    7043
# PaymentMethod       7043
# MonthlyCharges      7043
# TotalCharges        7043
# Churn               7043
# dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.describe(include='all')
# Out:
#         customerID gender  SeniorCitizen Partner Dependents       tenure  \
# count         7043   7043    7043.000000    7043       7043  7043.000000
# unique        7043      2            NaN       2          2          NaN
# top     7590-VHVEG   Male            NaN      No         No          NaN
# freq             1   3555            NaN    3641       4933          NaN
# mean           NaN    NaN       0.162147     NaN        NaN    32.371149
# std            NaN    NaN       0.368612     NaN        NaN    24.559481
# min            NaN    NaN       0.000000     NaN        NaN     0.000000
# 25%            NaN    NaN       0.000000     NaN        NaN     9.000000
# 50%            NaN    NaN       0.000000     NaN        NaN    29.000000
# 75%            NaN    NaN       0.000000     NaN        NaN    55.000000
# max            NaN    NaN       1.000000     NaN        NaN    72.000000
#
#        PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %% [markdown]
# <h3>Handle Missing Values</h3>

# %%
# Detecting the missing values
# Using error = ‘coerce’ will replace all non-numeric values with NaN
df.TotalCharges = pd.to_numeric(df.TotalCharges, errors='coerce')
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# 11 missing values in TotalCharges is too small with the dataset, so we drop them
df.dropna(how='any', inplace=True)
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# <h3>Data Visualization</h3>

# %%
# Visualize the target variable (Churn)
plt.figure(figsize=(5, 5))
sns.countplot(x=df['Churn'], palette='Blues', linewidth=1)
plt.show()

# %% [markdown]
# The plot shows a class imbalance of the data between churners and non-churners. To address this, resampling would be a suitable approach.

# %%
for i, predictor in enumerate(df.drop(columns=['Churn', 'TotalCharges', 'MonthlyCharges'])):
    plt.figure(i)
    sns.countplot(data=df, x=predictor, hue='Churn')

# %% [markdown]
# Relationship between Monthly Charges and Total Charges:

# %%
# Total Charges is the sum of Monthly Charges. 
sns.lmplot(data=df, x='MonthlyCharges', y='TotalCharges', fit_reg=False)

# %% [markdown]
# The TotalCharges and MonthlyCharges are highly correlated

# %%
# Customer Contract Distribution
sns.histplot(data=df, x='Churn', hue='Contract', multiple='dodge', shrink=0.8).set(title="Customer Contract Distribution")
# Out:
# [Text(0.5, 1.0, 'Customer Contract Distribution')]

# %% [markdown]
# About 75% of customers with Month-to-Month Contracts opted to move out as compared to 13% of customers with one-year contract and 3% with two-year contracts.

# %%
# Payment Method Distribution
plt.pie(df['PaymentMethod'].value_counts(), labels=df['PaymentMethod'].unique(), autopct='%1.2f%%')
plt.show()

# %% [markdown]
# The electronic check has the highest users.

# %%
# Dependents Distribution
sns.histplot(data=df, x='Churn', hue='Dependents', multiple='dodge', shrink=.8).set(title="Dependents Distribution")
# Out:
# [Text(0.5, 1.0, 'Dependents Distribution')]

# %% [markdown]
# Customers without dependents are more likely to churn

# %%
# Partners Distribution
sns.histplot(data=df, x='Churn', hue='Partner', multiple='dodge', shrink=.8).set(title="Partners Distribution")
# Out:
# [Text(0.5, 1.0, 'Partners Distribution')]

# %% [markdown]
# Customers that do not have partners are likely to churn more.

# %% [markdown]
# <h3>Customers with month-to-month contracts churn the most.
# Total charges and monthly charges were highly correlated</h3>
